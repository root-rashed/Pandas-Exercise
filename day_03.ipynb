# %% [markdown]
# Objects & DateTime Datatype

# %%
import pandas as pd

# %%
dates =['2026-10-04','2026-10-04','2026-10-04']
df =pd.DataFrame({'Date': dates})

# %%
df
# Out:
#          Date
# 0  2026-10-04
# 1  2026-10-04
# 2  2026-10-04

# %%
timestamps = pd.to_datetime(dates)

# %%
df2 = pd.DataFrame({'Date2': timestamps})

# %%
df2
# Out:
#        Date2
# 0 2026-10-04
# 1 2026-10-04
# 2 2026-10-04

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date2   3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 156.0 bytes

# %%
fuel = pd.read_csv("fuel.csv")

# %%
fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    22 non-null     object
#  1   sub_region                 22 non-null     object
#  2   iso3                       22 non-null     object
#  3   gasoline_usd_per_liter     22 non-null     float64
#  4   diesel_usd_per_liter       22 non-null     float64
#  5   lpg_usd_per_kg             22 non-null     float64
#  6   avg_monthly_income_usd     22 non-null     int64
#  7   fuel_affordability_index   22 non-null     float64
#  8   oil_import_dependency_pct  22 non-null     int64
#  9   refinery_capacity_kbpd     22 non-null     int64
#  10  ev_adoption_pct            22 non-null     float64
#  11  fuel_subsidy_active        22 non-null     bool
#  12  subsidy_cost_bn_usd        22 non-null     float64
# ...

# %%
fuel
# Out:
#         country      sub_region iso3  gasoline_usd_per_liter  \
# 0      Pakistan      South Asia  PAK                    1.64
# 1         India      South Asia  IND                    1.11
# 2    Bangladesh      South Asia  BGD                    1.07
# 3     Sri Lanka      South Asia  LKA                    1.34
# 4         Nepal      South Asia  NPL                    1.34
# 5   Afghanistan      South Asia  AFG                    0.86
# 6         China       East Asia  CHN                    1.26
# 7         Japan       East Asia  JPN                    1.15
# 8   South Korea       East Asia  KOR                    1.37
# 9        Taiwan       East Asia  TWN                    1.06
# 10     Mongolia       East Asia  MNG                    1.06
# 11     Thailand  Southeast Asia  THA                    1.24
# 12     Malaysia  Southeast Asia  MYS                    0.46
# 13    Indonesia  Southeast Asia  IDN                    0.61
# ...

# %%
import requests

# %%
from io import StringIO

# %%
url = 'https://github.com/tokern/piicatcher/blob/master/tests/samples/sample-data.csv'

# %%
response = requests.get(url)

# %%
csv = StringIO(response.text)

# %%
df = pd.DataFrame(csv)

# %%
df.head()
# Out:
#     0
# 0  \n
# 1  \n
# 2  \n
# 3  \n
# 4  \n

# %%
url = 'https://raw.githubusercontent.com/tokern/piicatcher/refs/heads/master/tests/samples/sample-data.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#              id gender   birthdate maiden_name      lname        fname  \
# 0   172-32-1176      m  1958/04/21       Smith      White      Johnson
# 1   514-14-8905      f  1944/12/22      Amaker     Borden       Ashley
# 2   213-46-8915      f  1958/04/21      Pinson      Green     Marjorie
# 3   524-02-7657      m  1962/03/25        Hall     Munsch       Jerome
# 4   489-36-8350      m  1964/09/06      Porter     Aragon       Robert
# 5   514-30-2668      f  1986/05/27   Nicholson    Russell        Jacki
# 6   505-88-5714      f  1963/09/23     Mcclain     Venson      Lillian
# 7   690-05-5315      m  1969/10/02       Kings     Conley       Thomas
# 8   646-44-9061      M  1978/01/12       Kurtz    Jackson      Charles
# 9   421-37-1396      f  1980/04/09      Linden      Davis        Susan
# 10  461-97-5660      f  1975/01/04     Kingdon     Watson         Gail
# 11  660-03-8360      f  1953/07/11     Onwunli   Garrison         Lisa
# ...

# %%
df.head()
# Out:
#             id gender   birthdate maiden_name   lname     fname  \
# 0  172-32-1176      m  1958/04/21       Smith   White   Johnson
# 1  514-14-8905      f  1944/12/22      Amaker  Borden    Ashley
# 2  213-46-8915      f  1958/04/21      Pinson   Green  Marjorie
# 3  524-02-7657      m  1962/03/25        Hall  Munsch    Jerome
# 4  489-36-8350      m  1964/09/06      Porter  Aragon    Robert
#
#                 address         city state    zip         phone  \
# 0        10932 Bigge Rd   Menlo Park    CA  94025  408 496-7223
# 1   4469 Sherman Street         Goff    KS  66428  785-939-6046
# 2     309 63rd St. #411      Oakland    CA  94618  415 986-7020
# 3        2183 Roy Alley   Centennial    CO  80112  303-901-6123
# 4  3181 White Oak Drive  Kansas City    MO  66215  816-645-6936
#
#                 email cc_type            cc_number  cc_cvc cc_expiredate
# 0   jwhite@domain.com       m  5270 4267 6450 5516     123    2010/06/25
# ...
