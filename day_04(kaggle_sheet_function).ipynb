# %% [markdown]
# Basic Functions in Pandas

# %%
import pandas as pd
df = pd.read_csv('fuel.csv')

# %% [markdown]
# Shape

# %%
row,col = df.shape

# %%
row
# Out:
# 22

# %%
col
# Out:
# 16

# %% [markdown]
# Top nth row

# %%
df.head(10)
# Out:
#        country  sub_region iso3  gasoline_usd_per_liter  diesel_usd_per_liter  \
# 0     Pakistan  South Asia  PAK                    1.64                  1.86
# 1        India  South Asia  IND                    1.11                  1.03
# 2   Bangladesh  South Asia  BGD                    1.07                  0.93
# 3    Sri Lanka  South Asia  LKA                    1.34                  1.19
# 4        Nepal  South Asia  NPL                    1.34                  1.21
# 5  Afghanistan  South Asia  AFG                    0.86                  0.81
# 6        China   East Asia  CHN                    1.26                  1.12
# 7        Japan   East Asia  JPN                    1.15                  1.04
# 8  South Korea   East Asia  KOR                    1.37                  1.22
# 9       Taiwan   East Asia  TWN                    1.06                  0.91
#
#    lpg_usd_per_kg  avg_monthly_income_usd  fuel_affordability_index  \
# ...

# %% [markdown]
# Last nth row

# %%
df.tail(10)
# Out:
#         country      sub_region iso3  gasoline_usd_per_liter  \
# 12     Malaysia  Southeast Asia  MYS                    0.46
# 13    Indonesia  Southeast Asia  IDN                    0.61
# 14      Vietnam  Southeast Asia  VNM                    1.09
# 15  Philippines  Southeast Asia  PHL                    1.26
# 16    Singapore  Southeast Asia  SGP                    2.53
# 17     Cambodia  Southeast Asia  KHM                    1.27
# 18      Myanmar  Southeast Asia  MMR                    1.12
# 19         Laos  Southeast Asia  LAO                    1.32
# 20       Brunei  Southeast Asia  BRN                    0.39
# 21  Timor-Leste  Southeast Asia  TLS                    1.38
#
#     diesel_usd_per_liter  lpg_usd_per_kg  avg_monthly_income_usd  \
# 12                  0.86            0.50                     820
# 13                  0.72            0.68                     320
# 14                  0.95            0.82                     280
# ...

# %% [markdown]
# Range of entries

# %%
df[5:10]
# Out:
#        country  sub_region iso3  gasoline_usd_per_liter  diesel_usd_per_liter  \
# 5  Afghanistan  South Asia  AFG                    0.86                  0.81
# 6        China   East Asia  CHN                    1.26                  1.12
# 7        Japan   East Asia  JPN                    1.15                  1.04
# 8  South Korea   East Asia  KOR                    1.37                  1.22
# 9       Taiwan   East Asia  TWN                    1.06                  0.91
#
#    lpg_usd_per_kg  avg_monthly_income_usd  fuel_affordability_index  \
# 5            0.85                      60                       2.3
# 6            0.82                     960                      25.4
# 7            1.20                    3200                      92.8
# 8            1.00                    2800                      68.1
# 9            0.85                    2200                      69.2
#
#    oil_import_dependency_pct  refinery_capacity_kbpd  ev_adoption_pct  \
# ...

# %% [markdown]
# Accessing Column

# %%
df.country
# Out:
# 0        Pakistan
# 1           India
# 2      Bangladesh
# 3       Sri Lanka
# 4           Nepal
# 5     Afghanistan
# 6           China
# 7           Japan
# 8     South Korea
# 9          Taiwan
# 10       Mongolia
# 11       Thailand
# 12       Malaysia
# 13      Indonesia
# 14        Vietnam
# 15    Philippines
# 16      Singapore
# 17       Cambodia
# 18        Myanmar
# 19           Laos
# 20         Brunei
# 21    Timor-Leste
# Name: country, dtype: object

# %%
df['country']
# Out:
# 0        Pakistan
# 1           India
# 2      Bangladesh
# 3       Sri Lanka
# 4           Nepal
# 5     Afghanistan
# 6           China
# 7           Japan
# 8     South Korea
# 9          Taiwan
# 10       Mongolia
# 11       Thailand
# 12       Malaysia
# 13      Indonesia
# 14        Vietnam
# 15    Philippines
# 16      Singapore
# 17       Cambodia
# 18        Myanmar
# 19           Laos
# 20         Brunei
# 21    Timor-Leste
# Name: country, dtype: object

# %% [markdown]
# Columns

# %%
df.columns
# Out:
# Index(['country', 'sub_region', 'iso3', 'gasoline_usd_per_liter',
#        'diesel_usd_per_liter', 'lpg_usd_per_kg', 'avg_monthly_income_usd',
#        'fuel_affordability_index', 'oil_import_dependency_pct',
#        'refinery_capacity_kbpd', 'ev_adoption_pct', 'fuel_subsidy_active',
#        'subsidy_cost_bn_usd', 'co2_transport_mt', 'price_date',
#        'gasoline_pct_daily_wage'],
#       dtype='object')

# %%
df[['country','sub_region']].head()
# Out:
#       country  sub_region
# 0    Pakistan  South Asia
# 1       India  South Asia
# 2  Bangladesh  South Asia
# 3   Sri Lanka  South Asia
# 4       Nepal  South Asia

# %% [markdown]
# Types of column

# %%
type(df.country)
# Out:
# pandas.core.series.Series

# %%
type(df[['country']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Maximum value in column

# %%
df['avg_monthly_income_usd'].max()
# Out:
# 4800

# %%
df['avg_monthly_income_usd'].min()
# Out:
# 60

# %%
df['avg_monthly_income_usd'].mean()
# Out:
# np.float64(931.8181818181819)

# %%
df['avg_monthly_income_usd'].std()
# Out:
# 1279.7047143166099

# %%
df['avg_monthly_income_usd'].mode()
# Out:
# 0     120
# 1     160
# 2     180
# 3     280
# 4    2200
# Name: avg_monthly_income_usd, dtype: int64

# %%
df['avg_monthly_income_usd'].value_counts()
# Out:
# avg_monthly_income_usd
# 180     2
# 160     2
# 120     2
# 280     2
# 2200    2
# 580     1
# 4800    1
# 310     1
# 320     1
# 820     1
# 2800    1
# 450     1
# 3200    1
# 960     1
# 60      1
# 210     1
# 110     1
# Name: count, dtype: int64

# %%
df['avg_monthly_income_usd'].quantile()
# Out:
# np.float64(295.0)

# %%
df.describe()
# Out:
#        gasoline_usd_per_liter  diesel_usd_per_liter  lpg_usd_per_kg  \
# count               22.000000             22.000000       22.000000
# mean                 1.178636              1.093182        0.954091
# std                  0.427265              0.360137        0.252373
# min                  0.390000              0.230000        0.300000
# 25%                  1.062500              0.935000        0.827500
# 50%                  1.195000              1.070000        0.965000
# 75%                  1.335000              1.185000        1.132500
# max                  2.530000              2.050000        1.350000
#
#        avg_monthly_income_usd  fuel_affordability_index  \
# count               22.000000                 22.000000
# mean               931.818182                 30.577273
# std               1279.704714                 44.764430
# min                 60.000000                  2.300000
# 25%                165.000000                  4.175000
# ...
