# %%
import pandas as pd

# %%
df =pd.read_csv("fuel.csv")

# %%
df.head(5)
# Out:
#       country  sub_region iso3  gasoline_usd_per_liter  diesel_usd_per_liter  \
# 0    Pakistan  South Asia  PAK                    1.64                  1.86
# 1       India  South Asia  IND                    1.11                  1.03
# 2  Bangladesh  South Asia  BGD                    1.07                  0.93
# 3   Sri Lanka  South Asia  LKA                    1.34                  1.19
# 4       Nepal  South Asia  NPL                    1.34                  1.21
#
#    lpg_usd_per_kg  avg_monthly_income_usd  fuel_affordability_index  \
# 0            1.25                     180                       3.7
# 1            1.08                     280                       8.4
# 2            0.98                     160                       5.0
# 3            1.18                     210                       5.2
# 4            1.28                     120                       3.0
#
#    oil_import_dependency_pct  refinery_capacity_kbpd  ev_adoption_pct  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    22 non-null     object
#  1   sub_region                 22 non-null     object
#  2   iso3                       22 non-null     object
#  3   gasoline_usd_per_liter     22 non-null     float64
#  4   diesel_usd_per_liter       22 non-null     float64
#  5   lpg_usd_per_kg             22 non-null     float64
#  6   avg_monthly_income_usd     22 non-null     int64
#  7   fuel_affordability_index   22 non-null     float64
#  8   oil_import_dependency_pct  22 non-null     int64
#  9   refinery_capacity_kbpd     22 non-null     int64
#  10  ev_adoption_pct            22 non-null     float64
#  11  fuel_subsidy_active        22 non-null     bool
#  12  subsidy_cost_bn_usd        22 non-null     float64
# ...

# %% [markdown]
# Delete Columns Using "del"

# %%
del df["iso3"]

# %%
df.head()
# Out:
#       country  sub_region  gasoline_usd_per_liter  diesel_usd_per_liter  \
# 0    Pakistan  South Asia                    1.64                  1.86
# 1       India  South Asia                    1.11                  1.03
# 2  Bangladesh  South Asia                    1.07                  0.93
# 3   Sri Lanka  South Asia                    1.34                  1.19
# 4       Nepal  South Asia                    1.34                  1.21
#
#    lpg_usd_per_kg  avg_monthly_income_usd  fuel_affordability_index  \
# 0            1.25                     180                       3.7
# 1            1.08                     280                       8.4
# 2            0.98                     160                       5.0
# 3            1.18                     210                       5.2
# 4            1.28                     120                       3.0
#
#    oil_import_dependency_pct  refinery_capacity_kbpd  ev_adoption_pct  \
# ...

# %% [markdown]
# Delete Columns Using "pop"

# %%
df.pop("sub_region")
# Out:
# 0         South Asia
# 1         South Asia
# 2         South Asia
# 3         South Asia
# 4         South Asia
# 5         South Asia
# 6          East Asia
# 7          East Asia
# 8          East Asia
# 9          East Asia
# 10         East Asia
# 11    Southeast Asia
# 12    Southeast Asia
# 13    Southeast Asia
# 14    Southeast Asia
# 15    Southeast Asia
# 16    Southeast Asia
# 17    Southeast Asia
# 18    Southeast Asia
# 19    Southeast Asia
# 20    Southeast Asia
# 21    Southeast Asia
# Name: sub_region, dtype: object

# %%
df.head()
# Out:
#       country  gasoline_usd_per_liter  diesel_usd_per_liter  lpg_usd_per_kg  \
# 0    Pakistan                    1.64                  1.86            1.25
# 1       India                    1.11                  1.03            1.08
# 2  Bangladesh                    1.07                  0.93            0.98
# 3   Sri Lanka                    1.34                  1.19            1.18
# 4       Nepal                    1.34                  1.21            1.28
#
#    avg_monthly_income_usd  fuel_affordability_index  \
# 0                     180                       3.7
# 1                     280                       8.4
# 2                     160                       5.0
# 3                     210                       5.2
# 4                     120                       3.0
#
#    oil_import_dependency_pct  refinery_capacity_kbpd  ev_adoption_pct  \
# 0                         85                     450              0.4
# ...

# %%
x =df.drop('ev_adoption_pct',axis=1).head()

# %%
x
# Out:
#       country  gasoline_usd_per_liter  diesel_usd_per_liter  lpg_usd_per_kg  \
# 0    Pakistan                    1.64                  1.86            1.25
# 1       India                    1.11                  1.03            1.08
# 2  Bangladesh                    1.07                  0.93            0.98
# 3   Sri Lanka                    1.34                  1.19            1.18
# 4       Nepal                    1.34                  1.21            1.28
#
#    avg_monthly_income_usd  fuel_affordability_index  \
# 0                     180                       3.7
# 1                     280                       8.4
# 2                     160                       5.0
# 3                     210                       5.2
# 4                     120                       3.0
#
#    oil_import_dependency_pct  refinery_capacity_kbpd  fuel_subsidy_active  \
# 0                         85                     450                 True
# ...

# %%
y = df[['ev_adoption_pct']]

# %%
y
# Out:
#     ev_adoption_pct
# 0               0.4
# 1               2.4
# 2               0.1
# 3               0.2
# 4               0.6
# 5               0.0
# 6              10.2
# 7               3.5
# 8              10.5
# 9               5.0
# 10              0.1
# 11              4.2
# 12              2.8
# 13              0.5
# 14              0.7
# 15              0.4
# 16              5.8
# 17              0.0
# 18              0.0
# 19              0.0
# 20              0.2
# 21              0.0

# %% [markdown]
# Delete Rows

# %%
df.drop([0,1],axis='index')
# Out:
#         country  gasoline_usd_per_liter  diesel_usd_per_liter  lpg_usd_per_kg  \
# 2    Bangladesh                    1.07                  0.93            0.98
# 3     Sri Lanka                    1.34                  1.19            1.18
# 4         Nepal                    1.34                  1.21            1.28
# 5   Afghanistan                    0.86                  0.81            0.85
# 6         China                    1.26                  1.12            0.82
# 7         Japan                    1.15                  1.04            1.20
# 8   South Korea                    1.37                  1.22            1.00
# 9        Taiwan                    1.06                  0.91            0.85
# 10     Mongolia                    1.06                  1.02            0.95
# 11     Thailand                    1.24                  1.10            0.78
# 12     Malaysia                    0.46                  0.86            0.50
# ...

# %%
d = df[df['gasoline_usd_per_liter']>1]

# %%
d
# Out:
#         country  gasoline_usd_per_liter  diesel_usd_per_liter  lpg_usd_per_kg  \
# 0      Pakistan                    1.64                  1.86            1.25
# 1         India                    1.11                  1.03            1.08
# 2    Bangladesh                    1.07                  0.93            0.98
# 3     Sri Lanka                    1.34                  1.19            1.18
# 4         Nepal                    1.34                  1.21            1.28
# 6         China                    1.26                  1.12            0.82
# 7         Japan                    1.15                  1.04            1.20
# 8   South Korea                    1.37                  1.22            1.00
# 9        Taiwan                    1.06                  0.91            0.85
# 10     Mongolia                    1.06                  1.02            0.95
# 11     Thailand                    1.24                  1.10            0.78
# ...

# %% [markdown]
# Rename and ConCate DataFrame

# %%
df1 =pd.DataFrame({'AGE':[10,20],'INCOME':[1000,2000]})
df2 =pd.DataFrame({'AGE':[30,40],'INCOME':[10000,20000]})

# %%
df1
# Out:
#    AGE  INCOME
# 0   10    1000
# 1   20    2000

# %%
df2
# Out:
#    AGE  INCOME
# 0   30   10000
# 1   40   20000

# %%
df1 = df1.rename(columns ={'AGE':'age','INCOME':'income'})
df2 = df2.rename(columns ={'AGE':'age','INCOME':'income'})

# %%
df1
# Out:
#    age  income
# 0   10    1000
# 1   20    2000

# %%
df2
# Out:
#    age  income
# 0   30   10000
# 1   40   20000

# %%
result = pd.concat([df1,df2],axis=1)
result
# Out:
#    age  income  age  income
# 0   10    1000   30   10000
# 1   20    2000   40   20000

# %%
rs = pd.concat([df1,df2])
rs
# Out:
#    age  income
# 0   10    1000
# 1   20    2000
# 0   30   10000
# 1   40   20000

# %% [markdown]
# NaN Value

# %%
dff = pd.read_excel("NaN_data.xlsx")
dff
# Out:
#      area  room     rent
# 0  1000.0   3.0  21000.0
# 1  1200.0   3.0  20000.0
# 2  1350.0   NaN      NaN
# 3  1400.0   3.0  21010.0
# 4  1200.0   NaN  20100.0
# 5     NaN   4.0  23170.0
# 6  1000.0   3.0  21000.0
# 7  1220.0   3.0  21000.0
# 8  1350.0   4.0  20370.0

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    8 non-null      float64
#  1   room    7 non-null      float64
#  2   rent    8 non-null      float64
# dtypes: float64(3)
# memory usage: 348.0 bytes

# %%
pd.isna(dff).sum()
# Out:
# area    1
# room    2
# rent    1
# dtype: int64

# %%
pd.isna(dff)
# Out:
#     area   room   rent
# 0  False  False  False
# 1  False  False  False
# 2  False   True   True
# 3  False  False  False
# 4  False   True  False
# 5   True  False  False
# 6  False  False  False
# 7  False  False  False
# 8  False  False  False

# %%
pd.isnull(dff)
# Out:
#     area   room   rent
# 0  False  False  False
# 1  False  False  False
# 2  False   True   True
# 3  False  False  False
# 4  False   True  False
# 5   True  False  False
# 6  False  False  False
# 7  False  False  False
# 8  False  False  False

# %%
pd.isnull(dff).sum()
# Out:
# area    1
# room    2
# rent    1
# dtype: int64
